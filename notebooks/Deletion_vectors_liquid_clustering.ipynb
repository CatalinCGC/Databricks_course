-- %%
--Read csv data from "dbfs:/databricks-datasets/online-retail/data-001/data.csv"
CREATE TABLE IF NOT EXISTS dev.bronze.sales AS
select * from 
read_files (
  '/Volumes/dev/bronze/volume/online-retail-dataset.csv',
  header => true,
  format => 'csv'
)

-- %%
select * from dev.bronze.sales

-- %%
describe extended dev.bronze.sales

-- %%
%python
spark.databricks.delta.allowArbitraryProperties.enabled='true'

-- %%
ALTER TABLE dev.bronze.sales SET TBLPROPERTIES ('delta.deletionVectors' = 'false')

-- %%
%python
display(dbutils.fs.ls('/databricks-datasets'))
